# %%
import numpy as np

# %% [markdown]
# ## Datatypes & Atributes

# %%
# Numpy's main datatype is ndarray (n dimentional array)
a1 = np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
# 61. video zamanında yapmıştım ancak kaybolmuş o yüzden bir deneme yapacağım
